# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt

# %%
# Read the books and the ratings data
books = pd.read_csv("./Resources/Books.csv", low_memory = False)
ratings = pd.read_csv("./Resources/Ratings.csv", low_memory = False)

#Combine both into a single DataFrame
book_ratings = books.merge(ratings, how = "outer", on = "ISBN")

# Display data for preview
book_ratings.head()
# Out:
#          ISBN           Book-Title           Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology    Mark P. O. Morford                2002
# 1  0002005018         Clara Callan  Richard Bruce Wright                2001
# 2  0002005018         Clara Callan  Richard Bruce Wright                2001
# 3  0002005018         Clara Callan  Richard Bruce Wright                2001
# 4  0002005018         Clara Callan  Richard Bruce Wright                2001
#
#                  Publisher   User-ID  Book-Rating
# 0  Oxford University Press       NaN          NaN
# 1    HarperFlamingo Canada       8.0          5.0
# 2    HarperFlamingo Canada   11676.0          8.0
# 3    HarperFlamingo Canada   67544.0          8.0
# 4    HarperFlamingo Canada  116866.0          9.0

# %%
book_ratings.dtypes
# Out:
# ISBN                    object
# Book-Title              object
# Book-Author             object
# Year-Of-Publication     object
# Publisher               object
# User-ID                float64
# Book-Rating            float64
# dtype: object

# %%
book_ratings.count()
# Out:
# ISBN                   555195
# Book-Title             505366
# Book-Author            505365
# Year-Of-Publication    505366
# Publisher              505364
# User-ID                433671
# Book-Rating            433671
# dtype: int64

# %%
book_ratings = book_ratings.dropna(how = "any")

# %%
book_ratings.count()
# Out:
# ISBN                   383839
# Book-Title             383839
# Book-Author            383839
# Year-Of-Publication    383839
# Publisher              383839
# User-ID                383839
# Book-Rating            383839
# dtype: int64

# %%
book_ratings
# Out:
#               ISBN                                     Book-Title  \
# 1       0002005018                                   Clara Callan
# 2       0002005018                                   Clara Callan
# 3       0002005018                                   Clara Callan
# 4       0002005018                                   Clara Callan
# 5       0002005018                                   Clara Callan
# ...            ...                                            ...
# 505352  0395264707                                     Dreamsnake
# 505358  1845170423                              Cocktail Classics
# 505360  0449906736  Flashpoints: Promise and Peril in a New World
# 505361  0440400988                     There's a Bat in Bunk Five
# 505362  0525447644                        From One to One Hundred
#
#                  Book-Author Year-Of-Publication  \
# 1       Richard Bruce Wright                2001
# 2       Richard Bruce Wright                2001
# 3       Richard Bruce Wright                2001
# 4       Richard Bruce Wright                2001
# 5       Richard Bruce Wright                2001
# ...                      ...                 ...
# 505352     Vonda N. McIntyre                1978
# 505358           David Biggs                2004
# 505360          Robin Wright                1993
# 505361        Paula Danziger                1988
# 505362            Teri Sloat                1991
#
#                               Publisher   User-ID  Book-Rating
# 1                 HarperFlamingo Canada       8.0          5.0
# 2                 HarperFlamingo Canada   11676.0          8.0
# 3                 HarperFlamingo Canada   67544.0          8.0
# 4                 HarperFlamingo Canada  116866.0          9.0
# 5                 HarperFlamingo Canada  123629.0          9.0
# ...                                 ...       ...          ...
# 505352                 Houghton Mifflin  275318.0         10.0
# 505358                        Connaught  275970.0          7.0
# 505360                 Ballantine Books  276313.0          5.0
# 505361  Random House Childrens Pub (Mm)  276463.0          7.0
# 505362                     Dutton Books  276579.0          4.0
#
# [383839 rows x 7 columns]

# %%
book_ratings["User-ID"] = pd.to_numeric(book_ratings["User-ID"], errors='coerce')

# %%
book_ratings["User-ID"] = book_ratings["User-ID"].astype(int)

# %%
book_ratings
# Out:
#               ISBN                                     Book-Title  \
# 1       0002005018                                   Clara Callan
# 2       0002005018                                   Clara Callan
# 3       0002005018                                   Clara Callan
# 4       0002005018                                   Clara Callan
# 5       0002005018                                   Clara Callan
# ...            ...                                            ...
# 505352  0395264707                                     Dreamsnake
# 505358  1845170423                              Cocktail Classics
# 505360  0449906736  Flashpoints: Promise and Peril in a New World
# 505361  0440400988                     There's a Bat in Bunk Five
# 505362  0525447644                        From One to One Hundred
#
#                  Book-Author Year-Of-Publication  \
# 1       Richard Bruce Wright                2001
# 2       Richard Bruce Wright                2001
# 3       Richard Bruce Wright                2001
# 4       Richard Bruce Wright                2001
# 5       Richard Bruce Wright                2001
# ...                      ...                 ...
# 505352     Vonda N. McIntyre                1978
# 505358           David Biggs                2004
# 505360          Robin Wright                1993
# 505361        Paula Danziger                1988
# 505362            Teri Sloat                1991
#
#                               Publisher  User-ID  Book-Rating
# 1                 HarperFlamingo Canada        8          5.0
# 2                 HarperFlamingo Canada    11676          8.0
# 3                 HarperFlamingo Canada    67544          8.0
# 4                 HarperFlamingo Canada   116866          9.0
# 5                 HarperFlamingo Canada   123629          9.0
# ...                                 ...      ...          ...
# 505352                 Houghton Mifflin   275318         10.0
# 505358                        Connaught   275970          7.0
# 505360                 Ballantine Books   276313          5.0
# 505361  Random House Childrens Pub (Mm)   276463          7.0
# 505362                     Dutton Books   276579          4.0
#
# [383839 rows x 7 columns]

# %%
book_ratings = book_ratings.reset_index()

# %%
# Assuming book_ratings is a DataFrame with a "Book-Title" column
title = book_ratings["Book-Title"]
counter = 0

def translate_to_english(title, translator):
    global counter
    try:
        # Translate the title to English
        translation = translator.translate(title, dest='en')
        counter += 1
        clear_output(wait=True)  # Clear the previous output
        display(f"Current count: {counter}")  # Display only the current count
        return translation.text
    except Exception as e:
        # Handle any potential errors during translation
#         print(f"Error translating '{title}': {str(e)}")
        return title

# Create a Translator object
translator = Translator()

# Apply translation to the 'Title' column
book_ratings['Translated Title'] = book_ratings["Book-Title"].apply(lambda x: translate_to_english(x, translator))

# Display the DataFrame with translated titles
print(book_ratings)
# Out:
# 'Current count: 80627'

# %%
# !pip install --upgrade transformers
# Out:
# Requirement already satisfied: transformers in c:\users\seeke\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy in c:\users\seeke\anaconda3\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: boto3 in c:\users\seeke\anaconda3\lib\site-packages (from transformers) (1.24.28)
# Requirement already satisfied: requests in c:\users\seeke\anaconda3\lib\site-packages (from transformers) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\seeke\anaconda3\lib\site-packages (from transformers) (4.65.0)
# Requirement already satisfied: regex in c:\users\seeke\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Collecting sentencepiece (from transformers)
#   Downloading sentencepiece-0.1.99-cp311-cp311-win_amd64.whl (977 kB)
#      ---------------------------------------- 0.0/977.5 kB ? eta -:--:--
#      --------- ---------------------------- 256.0/977.5 kB 7.9 MB/s eta 0:00:01
#      ----------------------------- -------- 768.0/977.5 kB 9.7 MB/s eta 0:00:01
#      -------------------------------------- 977.5/977.5 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: sacremoses in c:\users\seeke\anaconda3\lib\site-packages (from transformers) (0.0.43)
# Requirement already satisfied: botocore<1.28.0,>=1.27.28 in c:\users\seeke\anaconda3\lib\site-packages (from boto3->transformers) (1.27.59)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\seeke\anaconda3\lib\site-packages (from boto3->transformers) (0.10.0)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in c:\users\seeke\anaconda3\lib\site-packages (from boto3->transformers) (0.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\seeke\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\seeke\anaconda3\lib\site-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\seeke\anaconda3\lib\site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\seeke\anaconda3\lib\site-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: six in c:\users\seeke\anaconda3\lib\site-packages (from sacremoses->transformers) (1.16.0)
# Requirement already satisfied: click in c:\users\seeke\anaconda3\lib\site-packages (from sacremoses->transformers) (8.0.4)
# Requirement already satisfied: joblib in c:\users\seeke\anaconda3\lib\site-packages (from sacremoses->transformers) (1.2.0)
# Requirement already satisfied: colorama in c:\users\seeke\anaconda3\lib\site-packages (from tqdm->transformers) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\seeke\anaconda3\lib\site-packages (from botocore<1.28.0,>=1.27.28->boto3->transformers) (2.8.2)
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from transformers import AutoModelForConditionalGeneration, AutoTokenizer

model_name = "t5-base"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForConditionalGeneration.from_pretrained(model_name)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from transformers import AutoModelForConditionalGeneration, AutoTokenizer
#       3 model_name = "t5-base"
#       4 tokenizer = AutoTokenizer.from_pretrained(model_name)
#
# ImportError: cannot import name 'AutoModelForConditionalGeneration' from 'transformers' (C:\Users\Seeke\anaconda3\Lib\site-packages\transformers\__init__.py)

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer
import torch
from tqdm.auto import tqdm

# Initialize the model and tokenizer
model_name = "t5-base"
tokenizer = T5Tokenizer.from_pretrained(model_name)
model = T5ForConditionalGeneration.from_pretrained(model_name)

# Assuming book_ratings is a DataFrame with a "Book-Title" column
titles = book_ratings["Book-Title"].tolist()

def translate_titles(titles, model, tokenizer, batch_size=10):
    translated_texts = []
    for i in tqdm(range(0, len(titles), batch_size)):
        batch = titles[i:i+batch_size]
        inputs = tokenizer(batch, return_tensors="pt", padding=True, truncation=True, max_length=512).input_ids
        outputs = model.generate(inputs, max_length=40, num_beams=4, early_stopping=True)
        translated_batch = [tokenizer.decode(output, skip_special_tokens=True) for output in outputs]
        translated_texts.extend(translated_batch)
    return translated_texts

# Translate titles
translated_titles = translate_titles(titles, model, tokenizer)

# Update DataFrame
book_ratings['Translated Title'] = translated_titles

# Display or save your DataFrame
print(book_ratings.head())
# Out:
# WARNING:tensorflow:From C:\Users\Seeke\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Seeke\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from transformers import T5ForConditionalGeneration, T5Tokenizer
#       2 import torch
#       3 from tqdm.auto import tqdm
#
# ImportError: cannot import name 'T5ForConditionalGeneration' from 'transformers' (C:\Users\Seeke\anaconda3\Lib\site-packages\transformers\__init__.py)

# %%
book_ratings.nunique()

# %%
# Use Label Encoding from scikit-learn to encode ISBNs which are categorical
from sklearn.preprocessing import LabelEncoder

isbn_encoder = LabelEncoder()
book_ratings["ISBN_encoded"] = isbn_encoder.fit_transform(book_ratings["ISBN"])

# Reverse the encoding - we will use this to reverse the encoding later if needed
# book_ratings['ISBN_decoded'] = isbn_encoder.inverse_transform(book_ratings['ISBN_encoded'])

# %%
book_ratings.dtypes

# %%
display(book_ratings.loc(["ISBN_encoded"] == "074322678X"))

# %%
book_ratings.to_csv("Output/book_ratings.csv", index = False)

# %%
n_users = book_ratings["User-ID"].unique().shape[0]
n_items = book_ratings["ISBN_encoded"].unique().shape[0]
n_items = book_ratings["ISBN_encoded"].max()
A = np.zeros((n_users, n_items))

for line in dataset.itertuples():
    A[line[1] - 1, line[2] - 1] = line[3]

# %%
non_integer_rows = book_ratings[~book_ratings['ISBN_encoded'].apply(lambda x: isinstance(x, int))]

# %%
non_integer_rows
